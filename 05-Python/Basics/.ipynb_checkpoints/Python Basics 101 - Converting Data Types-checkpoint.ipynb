# %% [markdown]
# # Converting Data Types

# %%
num_int = 7

type(num_int)
# Out:
# int

# %%
num_str = '7'

type(num_str)
# Out:
# str

# %%
nun_str_conv = int(num_str)

type(nun_str_conv)
# Out:
# int

# %%
num_sum = num_int + nun_str_conv

print(num_sum)
# Out:
# 14

# %%
type(num_sum)
# Out:
# int

# %%
list_type = [1,2,3]

type(list_type)
# Out:
# list

# %%
type(tuple(list_type))
# Out:
# tuple

# %%
list_type = [1,2,3,3,2,1,2,3,2,1]

# %%
type(set(list_type))
# Out:
# set

# %%
dict_type = {'name': 'Elham','age': 38, 'hair': 'N/A'}

type(dict_type)
# Out:
# dict

# %%
dict_type.items()
# Out:
# dict_items([('name', 'Elham'), ('age', 38), ('hair', 'N/A')])

# %%
dict_type.values()
# Out:
# dict_values(['Elham', 38, 'N/A'])

# %%
dict_type.keys()
# Out:
# dict_keys(['name', 'age', 'hair'])

# %%
type(list(dict_type.keys()))
# Out:
# list

# %%
type(list(dict_type.values()))
# Out:
# list

# %%
long_str = "I like to party"

set(long_str)
# Out:
# {' ', 'I', 'a', 'e', 'i', 'k', 'l', 'o', 'p', 'r', 't', 'y'}
